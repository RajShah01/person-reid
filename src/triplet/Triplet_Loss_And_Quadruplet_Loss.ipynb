# %%
# !git clone https://github.com/huanghoujing/person-reid-triplet-loss-baseline.git
# Out:
# Cloning into 'person-reid-triplet-loss-baseline'...
# remote: Enumerating objects: 85, done.
# remote: Total 85 (delta 0), reused 0 (delta 0), pack-reused 85
# Unpacking objects: 100% (85/85), done.

# %% [markdown]
# ## Experiments

# %% [markdown]
# ## Pre-processing

# %%
# %%bash
#
# mkdir reid_data
# cd reid_data
# mkdir market
# mkdir duke
# mkdir cuhk

# %%
# !tar -xzvf '/content/drive/MyDrive/Triplet/person-reid-triplet-loss-baseline/market1501/images.tar.gz' -C '/content/reid_data/market'
# Out:
# Streaming output truncated to the last 5000 lines.
# images/00000746_0003_00000000.jpg
# images/00000836_0003_00000003.jpg
# images/00001082_0006_00000008.jpg
# images/00001377_0002_00000003.jpg
# images/00001125_0001_00000003.jpg
# images/00001256_0001_00000007.jpg
# images/00000623_0003_00000000.jpg
# images/00000911_0006_00000003.jpg
# images/00000715_0006_00000027.jpg
# images/00000776_0003_00000000.jpg
# images/00000733_0003_00000004.jpg
# images/00000242_0003_00000005.jpg
# images/00000094_0003_00000013.jpg
# images/00001355_0003_00000005.jpg
# images/00001440_0001_00000007.jpg
# images/00000899_0006_00000009.jpg
# images/00000861_0003_00000000.jpg
# images/00000668_0004_00000014.jpg
# images/00001119_0006_00000007.jpg
# images/00001188_0004_00000004.jpg
# images/00000352_0002_00000001.jpg
# images/00000191_0002_00000001.jpg
# images/00001348_0003_00000012.jpg
# images/00001053_0003_00000008.jpg
# images/00000653_0006_00000001.jpg
# images/00000116_0001_00000000.jpg
# ...

# %%
# !unzip -o "/content/drive/MyDrive/Datasets/cuhk03-20220317T055143Z-001.zip" -d '/content/drive/MyDrive/Datasets'
# Out:
# Archive:  /content/drive/MyDrive/Datasets/cuhk03-20220317T055143Z-001.zip
#   inflating: /content/drive/MyDrive/Datasets/cuhk03/re_ranking_train_test_split.pkl
#   inflating: /content/drive/MyDrive/Datasets/cuhk03/ori_to_new_im_name.pkl
#   inflating: /content/drive/MyDrive/Datasets/cuhk03/detected/partitions.pkl
#   inflating: /content/drive/MyDrive/Datasets/cuhk03/labeled/partitions.pkl
#   inflating: /content/drive/MyDrive/Datasets/cuhk03/detected/images.tar.gz
#   inflating: /content/drive/MyDrive/Datasets/cuhk03/labeled/images.tar.gz

# %%
# !unzip "/content/drive/MyDrive/Datasets/detected-20220221T170500Z-001.zip" -d '/content/reid_data'
# Out:
# Archive:  /content/drive/MyDrive/Datasets/detected-20220221T170500Z-001.zip
#   inflating: /content/reid_data/detected/partitions.pkl
#   inflating: /content/reid_data/detected/images.tar.gz

# %%
# !tar -xzvf "/content/drive/MyDrive/Datasets/cuhk03/labeled/images.tar.gz" -C '/content/reid_data/cuhk'
# Out:
# Streaming output truncated to the last 5000 lines.
# images/00000320_0000_00000003.jpg
# images/00000671_0000_00000001.jpg
# images/00000819_0000_00000003.jpg
# images/00001251_0001_00000004.jpg
# images/00000497_0000_00000001.jpg
# images/00000413_0001_00000001.jpg
# images/00001230_0001_00000000.jpg
# images/00000377_0001_00000002.jpg
# images/00001455_0000_00000000.jpg
# images/00000893_0000_00000002.jpg
# images/00000301_0001_00000004.jpg
# images/00000801_0000_00000003.jpg
# images/00000685_0001_00000004.jpg
# images/00001305_0000_00000000.jpg
# images/00000761_0001_00000001.jpg
# images/00000715_0001_00000004.jpg
# images/00000269_0001_00000002.jpg
# images/00001134_0001_00000004.jpg
# images/00000597_0000_00000003.jpg
# images/00001379_0001_00000000.jpg
# images/00000559_0000_00000002.jpg
# images/00000508_0000_00000001.jpg
# images/00000206_0000_00000003.jpg
# images/00000180_0001_00000004.jpg
# images/00000420_0000_00000000.jpg
# images/00001143_0001_00000003.jpg
# ...

# %%
# !tar -xzvf "/content/drive/MyDrive/Datasets/images.tar.gz" -C '/content/reid_data/duke'
# Out:
# Streaming output truncated to the last 5000 lines.
# images/00004736_0006_00000007.jpg
# images/00001174_0005_00000019.jpg
# images/00004380_0006_00000003.jpg
# images/00000723_0006_00000003.jpg
# images/00000283_0003_00000000.jpg
# images/00000624_0001_00000000.jpg
# images/00000035_0002_00000001.jpg
# images/00001785_0004_00000000.jpg
# images/00000153_0007_00000003.jpg
# images/00000777_0002_00000004.jpg
# images/00000405_0001_00000001.jpg
# images/00000137_0002_00000000.jpg
# images/00000789_0001_00000004.jpg
# images/00000166_0005_00000030.jpg
# images/00000360_0006_00000006.jpg
# images/00004631_0006_00000001.jpg
# images/00000595_0004_00000006.jpg
# images/00004726_0006_00000027.jpg
# images/00000112_0001_00000006.jpg
# images/00000628_0001_00000003.jpg
# images/00000435_0004_00000004.jpg
# images/00000192_0002_00000003.jpg
# images/00000381_0004_00000006.jpg
# images/00006368_0008_00000007.jpg
# images/00006476_0008_00000341.jpg
# images/00006476_0008_00000140.jpg
# ...

# %%
# !cp '/content/drive/MyDrive/Triplet/person-reid-triplet-loss-baseline/market1501/partitions.pkl' '/content/reid_data/market'

# %%
# !cp '/content/drive/MyDrive/Datasets/partitions_duke.pkl' '/content/reid_data/duke'

# %%
# !cp '/content/drive/MyDrive/Datasets/partitions_cuhk.pkl' '/content/reid_data/cuhk'

# %%
# !cp '/content/drive/MyDrive/Datasets/cuhk03/labeled/partitions_cuhk.pkl' '/content/reid_data/cuhk'

# %%
cd /content/drive/MyDrive/Triplet/person-reid-triplet-loss-baseline
# Out:
# /content/drive/MyDrive/Triplet/person-reid-triplet-loss-baseline

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 125 kB 4.3 MB/s
# ...

# %% [markdown]
# ## **Triplet Loss Function**

# %% [markdown]
# ## M -> M

# %%
#Euclidian Distance (M -> M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'market1501' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 5 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'epochs_per_val': 5,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-15_17:27:20.txt',
# ...

# %%
#Cosine Distance (M -> M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'market1501' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 5 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'epochs_per_val': 5,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-16_14:15:34.txt',
# ...

# %% [markdown]
# ## D -> D

# %%
#Eucledian Distance (D -> D)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 5 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 5,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-02-23_17:11:24.txt',
# ...

# %%
#Cosine Distance (D -> D)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 5 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 5,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-10_07:58:59.txt',
# ...

# %% [markdown]
# ## C -> C

# %%
#Euclidian Distance (C->C)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'cuhk03' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 5 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'cuhk03',
#  'epochs_per_val': 5,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-02-28_08:29:34.txt',
# ...

# %%
#Cosine Distance (C -> C)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'cuhk03' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 5 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'cuhk03',
#  'epochs_per_val': 5,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-02-28_09:09:43.txt',
# ...

# %% [markdown]
# ## M + D + C -> M

# %%
# !python script/dataset/combine_trainval_sets.py
# Out:
# Partition file saved to /content/reid_data/partitions.pkl

# %%
#Euclidian Distance (Com->M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 25,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-27_07:57:36.txt',
# ...

# %% [markdown]
# ## D -> M

# %%
#Eucledian Distance (D->M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-21_16:13:51.txt',
# ...

# %%
#Eucledian Distance (D->M contd)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --resume True --steps_per_log 1 --epochs_per_val 10 --total_epochs 20
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': True,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-21_17:05:36.txt',
# ...

# %%
#Eucledian Distance (D->M contd 2)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --resume True --steps_per_log 1 --epochs_per_val 50 --total_epochs 50
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 50,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': True,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-22_19:35:53.txt',
# ...

# %%
#Eucledian Distance (D->M contd 2)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --resume True --steps_per_log 1 --epochs_per_val 100 --total_epochs 100
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 100,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': True,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-23_06:29:24.txt',
# ...

# %%
#Cosine Distance (D -> Market)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-21_16:16:24.txt',
# ...

# %% [markdown]
# ## **C + D -> M**

# %%
# !python script/dataset/combine_trainval_sets_dc_m.py
# Out:
# Partition file saved to /content/reid_data/partitions.pkl

# %%
#Euclidian Distance (Com->M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-20_09:44:15.txt',
# ...

# %%
#Eucledian Distance (Combined->M contd 2)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 50 --total_epochs 50

# %% [markdown]
# ## M -> D

# %%
#Eucledian Distance (M -> D)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'market1501' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 50 --total_epochs 50
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'epochs_per_val': 50,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-22_20:29:58.txt',
# ...

# %%
#Cosine Distance (M -> D)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'market1501' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-21_19:47:32.txt',
# ...

# %% [markdown]
# ## M + C -> D

# %%
# !python script/dataset/combine_trainval_sets_mc_d.py
# Out:
# Partition file saved to /content/reid_data/partitions.pkl

# %%
#Euclidian Distance (Combined -> Duke) 
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-18_06:39:23.txt',
# ...

# %%
#Cosine Distance (Combined -> Duke)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-20_07:44:15.txt',
# ...

# %% [markdown]
# ## M + D -> C

# %%
# !python script/dataset/combine_trainval_sets_md_c.py
# Out:
# Partition file saved to /content/reid_data/partitions.pkl

# %%
#Euclidian Distance (Combined -> CUHK03)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-20_07:59:10.txt',
# ...

# %%
#Cosine Distance (Combined -> CUHK03)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-03-20_08:46:35.txt',
# ...

# %%
#Cosine Distance (D -> M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'market1501' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-17_07:33:59.txt',
# ...

# %% [markdown]
# ## **Quadruplet Loss**

# %% [markdown]
# ## M -> D

# %%
#Euclidian Distance (M -> D)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'market1501' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'market1501',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-18_18:12:37.txt',
# ...

# %% [markdown]
# ## D -> M

# %%
#Euclidian Distance (D -> M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-18_18:32:29.txt',
# ...

# %%
#Eucledian Distance (D->M contd 2)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'duke' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --resume True --steps_per_log 1 --epochs_per_val 25 --total_epochs 25
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'duke',
#  'epochs_per_val': 25,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': True,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-18_19:36:31.txt',
# ...

# %% [markdown]
# ## D + C -> M

# %%
# !python script/dataset/combine_trainval_sets_dc_m.py
# Out:
# Partition file saved to /content/reid_data/partitions.pkl

# %%
#Euclidian Distance (Com->M)
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-19_15:57:53.txt',
# ...

# %% [markdown]
# ## M + C -> D

# %%
# !python script/dataset/combine_trainval_sets_mc_d.py
# Out:
# Partition file saved to /content/reid_data/partitions.pkl

# %%
#Euclidian Distance (Combined -> Duke) 
# !python script/experiment/train.py -d '(0,)' --only_test false --dataset 'combined' --last_conv_stride 1 --normalize_feature false --trainset_part trainval --exp_dir '/content/drive/MyDrive/train_log' --steps_per_log 1 --epochs_per_val 10 --total_epochs 10
# Out:
# ------------------------------------------------------------
# cfg.__dict__
# {'base_lr': 0.0002,
#  'ckpt_file': '/content/drive/MyDrive/train_log/ckpt.pth',
#  'crop_prob': 0,
#  'crop_ratio': 1,
#  'dataset': 'combined',
#  'epochs_per_val': 10,
#  'exp_decay_at_epoch': 151,
#  'exp_dir': '/content/drive/MyDrive/train_log',
#  'ids_per_batch': 32,
#  'im_mean': [0.486, 0.459, 0.408],
#  'im_std': [0.229, 0.224, 0.225],
#  'ims_per_id': 4,
#  'last_conv_stride': 1,
#  'log_to_file': True,
#  'lr_decay_type': 'exp',
#  'margin': 0.3,
#  'model_weight_file': '',
#  'normalize_feature': False,
#  'only_test': False,
#  'prefetch_threads': 2,
#  'resize_h_w': (256, 128),
#  'resume': False,
#  'run': 1,
#  'scale_im': True,
#  'seed': None,
#  'staircase_decay_at_epochs': (101, 201),
#  'staircase_decay_multiply_factor': 0.1,
#  'stderr_file': '/content/drive/MyDrive/train_log/stderr_2022-04-19_15:14:40.txt',
# ...
